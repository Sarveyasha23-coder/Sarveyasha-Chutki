# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

sns.set_style("whitegrid")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5
#       6 from sklearn.preprocessing import StandardScaler, PowerTransformer
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
df = pd.read_csv("../data/raw/03_Clustering_Marketing.csv")

df.columns = df.columns.str.lower().str.strip()
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df = pd.read_csv("../data/raw/03_Clustering_Marketing.csv")
#       2
#       3 df.columns = df.columns.str.lower().str.strip()
#       4 df.head()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.info()
#       2 df.describe()
#       3 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
sns.histplot(df['age'], kde=True)
plt.title("Age Distribution")
plt.show()

sns.countplot(x='gender', data=df)
plt.title("Gender Distribution")
plt.show()

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
df = df.dropna()

X = df.select_dtypes(include=['int64', 'float64'])

# Transform skewness
pt = PowerTransformer(method='yeo-johnson')
X_transformed = pt.fit_transform(X)

# Scale data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_transformed)
# Out:
# Running cells with 'Python 3.14.4' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/HP/AppData/Local/Programs/Python/Python314/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.scatter(X_pca[:,0], X_pca[:,1])
plt.title("PCA Projection")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pca = PCA(n_components=2)
#       2 X_pca = pca.fit_transform(X_scaled)
#       3
#       4 plt.scatter(X_pca[:,0], X_pca[:,1])
#
# NameError: name 'PCA' is not defined

# %%
wcss = []
for i in range(1, 10):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,10), wcss, marker='o')
plt.title("Elbow Method")
plt.show()
# Out:
# Running cells with 'Python 3.12.10' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/HP/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
labels = kmeans.fit_predict(X_scaled)

kmeans_score = silhouette_score(X_scaled, labels)
print("K-Means Score:", kmeans_score)

df['cluster'] = labels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 kmeans = KMeans(n_clusters=3, random_state=42)
#       2 labels = kmeans.fit_predict(X_scaled)
#       3
#       4 kmeans_score = silhouette_score(X_scaled, labels)
#
# NameError: name 'KMeans' is not defined

# %%
plt.scatter(X_pca[:,0], X_pca[:,1], c=df['cluster'])
plt.title("Clusters (PCA)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.scatter(X_pca[:,0], X_pca[:,1], c=df['cluster'])
#       2 plt.title("Clusters (PCA)")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.groupby('cluster').mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.groupby('cluster').mean()
#
# NameError: name 'df' is not defined

# %%
sns.countplot(x='cluster', hue='gender', data=df)
plt.title("Gender per Cluster")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sns.countplot(x='cluster', hue='gender', data=df)
#       2 plt.title("Gender per Cluster")
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
# Hierarchical
hier = AgglomerativeClustering(n_clusters=3)
hier_labels = hier.fit_predict(X_scaled)
hier_score = silhouette_score(X_scaled, hier_labels)

# DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
db_labels = dbscan.fit_predict(X_scaled)

mask = db_labels != -1
db_score = silhouette_score(X_scaled[mask], db_labels[mask])

print("KMeans:", kmeans_score)
print("Hierarchical:", hier_score)
print("DBSCAN:", db_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Hierarchical
# ----> 2 hier = AgglomerativeClustering(n_clusters=3)
#       3 hier_labels = hier.fit_predict(X_scaled)
#       4 hier_score = silhouette_score(X_scaled, hier_labels)
#       5
#
# NameError: name 'AgglomerativeClustering' is not defined

# %%
anime = pd.read_csv("../data/raw/anime.csv")
rating = pd.read_csv("../data/raw/rating.csv")

anime.head()
rating.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 anime = pd.read_csv("../data/raw/anime.csv")
#       2 rating = pd.read_csv("../data/raw/rating.csv")
#       3
#       4 anime.head()
#
# NameError: name 'pd' is not defined

# %%
anime.info()
anime.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 anime.info()
#       2 anime.isnull().sum()
#
# NameError: name 'anime' is not defined

# %%
sns.histplot(anime['rating'], kde=True)
plt.title("Anime Rating Distribution")
plt.show()

top_anime = anime.sort_values(by='members', ascending=False).head(10)

sns.barplot(x='members', y='name', data=top_anime)
plt.title("Top Anime")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.histplot(anime['rating'], kde=True)
#       2 plt.title("Anime Rating Distribution")
#       3 plt.show()
#       4
#
# NameError: name 'sns' is not defined

# %%
anime_cb = anime[['anime_id', 'name', 'genre', 'type', 'rating']]

anime_cb['genre'] = anime_cb['genre'].fillna('')
anime_cb['type'] = anime_cb['type'].fillna('')
anime_cb['rating'] = anime_cb['rating'].fillna(0)

anime_cb['content'] = (
    anime_cb['genre'] + " " +
    anime_cb['type'] + " " +
    anime_cb['rating'].astype(str)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 anime_cb = anime[['anime_id', 'name', 'genre', 'type', 'rating']]
#       2
#       3 anime_cb['genre'] = anime_cb['genre'].fillna('')
#       4 anime_cb['type'] = anime_cb['type'].fillna('')
#
# NameError: name 'anime' is not defined

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(anime_cb['content'])

cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

indices = pd.Series(anime_cb.index, index=anime_cb['name']).drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tfidf = TfidfVectorizer(stop_words='english')
#       2 tfidf_matrix = tfidf.fit_transform(anime_cb['content'])
#       3
#       4 cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
#
# NameError: name 'TfidfVectorizer' is not defined

# %%
def recommend_anime(title, top_n=10):
    if title not in indices:
        return "Anime not found"

    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))

    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n+1]

    anime_indices = [i[0] for i in sim_scores]

    return anime_cb['name'].iloc[anime_indices]

# %%
recommend_anime("Naruto", 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 recommend_anime("Naruto", 10)
#
# Cell In[12], line 2, in recommend_anime(title, top_n)
#       1 def recommend_anime(title, top_n=10):
# ----> 2     if title not in indices:
#       3         return "Anime not found"
#       4
#       5     idx = indices[title]
#
# NameError: name 'indices' is not defined
